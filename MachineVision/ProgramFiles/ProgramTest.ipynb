# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread("/workspaces/MyProgrammingSpace/MachineVisionMaterials/images/castara.jpeg")
plt.imshow(image)

# %%
rgbImage = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgbImage)

# %%
grayImage = cv2.cvtColor(rgbImage, cv2.COLOR_RGB2GRAY)
plt.imshow(grayImage, cmap='gray')

# %%
grayImage.shape
# Out:
# (1280, 960)
