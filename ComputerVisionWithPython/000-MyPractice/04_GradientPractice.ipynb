# %%
## Importing Libraries ##
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
## Printing Image in Large size ##
def showImg(imgMat):
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.imshow(imgMat, cmap='gray')

# %%
img = cv.imread("../DATA/sudoku.jpg", cv.IMREAD_GRAYSCALE)
laplacian = cv.Laplacian(img, cv.CV_64F)
showImg(laplacian)

# %%
cv.Laplacian(img, d)

# %%
showImg(soblex)
